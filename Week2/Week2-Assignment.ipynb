# %% [markdown]
# DSC540-T301<br>
# Week 2 Assignment<br>
# Jeremy Barton

# %% [markdown]
# #### Introduction

# %% [markdown]
# This notebook will use aviation data to make three visualizations or plots. The data is accessed via a SQLite database for reproducability purposes. It mimics data collected from the OpenSkyAPI which provides real-time flight data and can be used to track aircrafts.
#
# There are several uses for this type of data which include but not limited to:
#
# - Air Traffic Management
# - Anomaly detection
# - Aviation research
# - Security and surveillance

# %% [markdown]
# #### Question

# %% [markdown]
# For the purpose of this exercise we would like to know, <b> what is the average speed of each aircraft, how far are they and what is the distribution speed of speed of each aircraft within a given radius?</b>
#
# This is what each of the three graphs will answer. For decorative purposes a greenscale will be used as it might appear in a cockpit of an aircraft.

# %% [markdown]
# #### Visualization

# %%
# Imports and preprocessing
